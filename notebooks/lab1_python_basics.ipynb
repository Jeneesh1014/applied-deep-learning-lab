# %% [markdown]
# # Python basics
#
# Follow the instructions below and write down the requested texts or code directly in the Jupyter notebook.

# %% [markdown]
# ## Code comprehension
#
# Try to understand the following code snippet WITHOUT executing it. Write down ...:
#
# 1. ... the result of the program
# 2. ... a comment describing the semantics of the small program.

# %%
numbers = [1, -10, 0, -5, -1000, 100, 7]
maximum = numbers[0]

for num in numbers:
    if num > maximum:
        maximum = num

print("Result: ", maximum)
# Out:
# Result:  100

# %% [markdown]
# 1. Result: 100
# 2. here the list is given and we are comparing with the first element first and then if number is more we choose that number that way we are finding the maximum number.

# %% [markdown]
# ## Coding basics
#
# Understand the syntax and semantics of the following code snippets. Modify parameters or whole statements to see the effects.
# Task: Answer the questions asked for each code statement and write the answer either as markdown or code comment.

# %% [markdown]
# **Snippet 1**: What property of Python is demonstrated with the following statement?

# %%
x = 132453
print(type(x))
x = "Game of thrones"
print(type(x))
x = True
print(type(x))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# Here we are using type inbuild function which returns what type are we using.

# %% [markdown]
# **Snippet 2:** The following code snippet demonstrates one variant for list slicing. Which slicing variants (in terms of start and end indices) are supported by Python and what do they mean? Write down an example for each variant! Does this also work with strings?

# %%
# Initialize list
lst = [1, 2, 3, 4, 5, 6, 7, 8, 9]

# Slice from index 2 to 5
print(lst[2:6]) # Output: [3, 4, 5, 6]

# reverse the list
print(lst[::-1])

print(lst[1:5:2])
# Out:
# [3, 4, 5, 6]
# [9, 8, 7, 6, 5, 4, 3, 2, 1]
# [2, 4]

# %% [markdown]
# I think we can slice or get any kind of list with the help of list slicing with many functionalities like inverse or ...

# %% [markdown]
# **Snippet 3**: This time only comments are provided. Fill the line below each comment with the correct statement (imports might be necessary, too).

# %%
import random as rand
# initialize a variable n to a random integer between 0 and 10 (incl. range limits).
n = rand.randint(0, 10)
result = [n*n if n>=5 else (n if n==0 else -n) ]
# If the number is lower than 5 but higher than 0, invert it (change sign).

# If the number is 0 do nothing
result

# print the result to the console
# Out:
# 10

# %% [markdown]
# **Snippet 4**: Refactor the following statements to Python functions.

# %%
print("area(1, 5) = ", 1 * 5)
print("area(1.5, 2.4) = ", 1.5 * 2.4)
print("is_square(1, 8) = ", 1 == 8)
print("is_square(8, 8) = ", 8 == 8)


def area(a,b):
    return a*b

def is_square(a,b):
    return a==b
# Out:
# area(1, 5) =  5
# area(1.5, 2.4) =  3.5999999999999996
# is_square(1, 8) =  False
# is_square(8, 8) =  True

# %% [markdown]
# **Snippet 5**: Copy the function and the function calls you created for "area". If not done, yet, change calls such that they use keyword arguments. Alter the argument ordering. What are the advantages of keyword arguments? Write down two of these advantages!
#
# Afterwards, introduce a parameter "user_name" with a default value.
# Alter the printed output, such that it includes the "user_name".

# %%
def area(a,b,user_name="Jeneesh"):
    result = a*b
    return result

# %% [markdown]
# Advantages
#
# 1. order doesn't matter
# 2. code is more readable as we are already know which paramter to give which input

# %% [markdown]
# **Snippet 6**: Implement the following description based on Python classes:
#
# - A building consists of rooms
# - A building can be initialized with a list of rooms
# - A building has a size and a location given as two floating point coordinates
# - Each room has a number, a capacity and several properties described in natural language
# - It needs to be asserted that the room number is in the range of 1 to 100
# - A building allows for swapping the room numbers of two rooms

# %%
from typing import List

class Room:
    def __init__(self, number: int, capacity: int, properties: List[str]):
        assert 1 <= number <= 100, "Room number must be between 1 and 100."

        self.number = number
        self.capacity = capacity
        self.properties = properties


class Building:
    def __init__(self, rooms: List[Room], size: float, location: tuple):
        self.rooms = rooms
        self.size = size
        self.location = location

    def swap_room_numbers(self, room1: Room, room2: Room):
        room1.number, room2.number = room2.number, room1.number


room1 = Room(45, 10, ["Projector", "Air Conditioned"])
room2 = Room(46, 20, ["Whiteboard"])

building = Building(
    [room1, room2],
    1500.0,
    (50.1234, 12.5678)
)

building.swap_room_numbers(room1, room2)

print(room1.number)
print(room2.number)
# Out:
# 46
# 45

# %% [markdown]
# # Python Basics – Exam Reference Notes
#
# ## Applied Deep Learning (ADL)
#
# > **Purpose:** These notes summarize the most important Python basics from the first ADL practical. They focus on concepts that are **most likely to appear in a written university exam**, where students are usually expected to explain concepts rather than write long programs.
#
# ---
#
# # 1. Code Comprehension
#
# ## Q1. What does the following program do?
#
# ```python
# numbers = [1, -10, 0, -5, -1000, 100, 7]
# maximum = numbers[0]
#
# for num in numbers:
#     if num > maximum:
#         maximum = num
#
# print(maximum)
# ```
#
# ### Answer
#
# The program finds the **maximum (largest) element** in a list.
#
# It initializes the variable `maximum` with the first element of the list. Then it iterates through each element using a `for` loop. During each iteration, the current element is compared with the stored maximum value. If a larger value is found, the maximum variable is updated. After all elements have been checked, the largest value is printed.
#
# ---
#
# ## Q2. Why is the first element used instead of writing `maximum = 0`?
#
# ### Answer
#
# The first element is used because the list may contain only negative numbers. If `maximum` were initialized to `0`, the algorithm would produce incorrect results when all elements are negative. Initializing with the first element guarantees that the maximum value always belongs to the list.
#
# ---
#
# # 2. Dynamic Typing
#
# ## Q3. What property of Python is demonstrated by the following code?
#
# ```python
# x = 132453
# x = "Game of Thrones"
# x = True
# ```
#
# ### Answer
#
# The code demonstrates **dynamic typing**.
#
# Python is a dynamically typed programming language, meaning that variables do not have fixed data types. A variable can store values of different data types during program execution without requiring explicit type declarations. The data type is determined automatically at runtime.
#
# ---
#
# ## Q4. What is the purpose of the `type()` function?
#
# ### Answer
#
# The `type()` function returns the data type (class) of an object. It is commonly used to determine whether a variable contains an integer, string, Boolean, list, float, or another data type.
#
# Example:
#
# ```python
# type(10)      # int
# type("Hello") # str
# type(True)    # bool
# ```
#
# ---
#
# # 3. List Slicing
#
# ## Q5. What is list slicing?
#
# ### Answer
#
# List slicing is a technique used to extract a portion of a list by specifying a start index, stop index, and optional step size. The start index is included, while the stop index is excluded.
#
# General syntax:
#
# ```python
# list[start : stop : step]
# ```
#
# ---
#
# ## Q6. Explain the different slicing variants.
#
# | Syntax                  | Description                                                                      |
# | ----------------------- | -------------------------------------------------------------------------------- |
# | `list[start:stop]`      | Returns elements from the start index (inclusive) to the stop index (exclusive). |
# | `list[start:]`          | Returns all elements from the specified start index to the end of the list.      |
# | `list[:stop]`           | Returns all elements from the beginning up to the stop index (exclusive).        |
# | `list[:]`               | Returns a copy of the entire list.                                               |
# | `list[start:stop:step]` | Returns elements using the specified step size.                                  |
# | `list[::-1]`            | Returns the list in reverse order.                                               |
#
# ---
#
# ## Q7. Does slicing also work for strings?
#
# ### Answer
#
# Yes.
#
# Strings are sequence data types in Python, just like lists. Therefore, string slicing follows exactly the same syntax and behavior as list slicing.
#
# Example:
#
# ```python
# text = "Python"
#
# text[1:4]   # "yth"
# text[::-1]  # "nohtyP"
# ```
#
# ---
#
# ## Q8. State three important rules of Python slicing.
#
# ### Answer
#
# 1. The **start index is included**, while the **stop index is excluded**.
# 2. A **positive step** moves from left to right, whereas a **negative step** moves from right to left.
# 3. If the direction of the step does not match the start and stop indices, the result is an empty list.
#
# ---
#
# # 4. Random Numbers
#
# ## Q9. What is the purpose of `random.randint(a, b)`?
#
# ### Answer
#
# The function `random.randint(a, b)` generates and returns a random integer between `a` and `b`, including both boundary values.
#
# Example:
#
# ```python
# import random
#
# number = random.randint(0,10)
# ```
#
# Possible outputs:
#
# ```
# 0
# 4
# 8
# 10
# ```
#
# ---
#
# # 5. Conditional Expressions
#
# ## Q10. What is Python's conditional (ternary) operator?
#
# ### Answer
#
# Python provides a one-line conditional expression that evaluates one value if the condition is true and another value if the condition is false.
#
# General syntax:
#
# ```python
# value_if_true if condition else value_if_false
# ```
#
# Example:
#
# ```python
# result = n*n if n >= 5 else -n
# ```
#
# It provides a shorter alternative to an `if-else` statement.
#
# ---
#
# # 6. Functions
#
# ## Q11. What is a function?
#
# ### Answer
#
# A function is a reusable block of code that performs a specific task. Functions improve code organization, reduce duplication, increase readability, and make programs easier to maintain.
#
# ---
#
# ## Q12. What is the difference between defining and calling a function?
#
# ### Answer
#
# **Function Definition**
#
# A function definition specifies the function name, parameters, and body using the `def` keyword.
#
# **Function Call**
#
# A function call executes the function by providing the required arguments.
#
# ---
#
# ## Q13. What is the purpose of the `return` statement?
#
# ### Answer
#
# The `return` statement sends a value from a function back to the caller. Once a `return` statement is executed, the function terminates immediately.
#
# ---
#
# # 7. Keyword Arguments
#
# ## Q14. What are keyword arguments?
#
# ### Answer
#
# Keyword arguments are arguments passed to a function by specifying the parameter name together with its value.
#
# Example:
#
# ```python
# area(width=5, length=10)
# ```
#
# ---
#
# ## Q15. State two advantages of keyword arguments.
#
# ### Answer
#
# 1. Arguments can be passed in any order because they are matched by parameter name.
# 2. They improve code readability by clearly indicating which value belongs to which parameter.
#
# ---
#
# # 8. Default Parameters
#
# ## Q16. What is a default parameter?
#
# ### Answer
#
# A default parameter is a function parameter that already has a predefined value. If no argument is supplied during the function call, the default value is used automatically.
#
# Example:
#
# ```python
# def greet(name="Guest"):
#     print(name)
# ```
#
# ---
#
# # 9. Python Classes
#
# ## Q17. What is a class?
#
# ### Answer
#
# A class is a blueprint or template used to create objects. It defines the attributes (data) and methods (functions) that all objects of that class will possess.
#
# ---
#
# ## Q18. What is an object?
#
# ### Answer
#
# An object is an instance of a class. It represents a real-world entity with its own attributes and behavior.
#
# ---
#
# ## Q19. What is the purpose of the `__init__()` method?
#
# ### Answer
#
# The `__init__()` method is a special constructor that is automatically executed whenever an object is created. It is used to initialize the attributes of the object.
#
# ---
#
# ## Q20. What is the purpose of the `__str__()` method?
#
# ### Answer
#
# The `__str__()` method returns a human-readable string representation of an object. It is automatically called when the object is printed using the `print()` function.
#
# ---
#
# # 10. Assertions
#
# ## Q21. What is the purpose of the `assert` statement?
#
# ### Answer
#
# The `assert` statement is used to verify that a condition is true during program execution. If the condition evaluates to `False`, Python raises an `AssertionError`. Assertions are commonly used for debugging and validating program inputs.
#
# ---
#
# # 11. Building and Room Example
#
# ## Q22. Why was an assertion used for the room number?
#
# ### Answer
#
# The assertion ensures that every room number is valid and lies within the required range (1–100). If an invalid room number is provided, the program immediately raises an error, preventing incorrect object creation.
#
# ---
#
# ## Q23. Why does the Building class receive a list of Room objects?
#
# ### Answer
#
# A building consists of multiple rooms. Therefore, storing the rooms as a list allows the Building object to manage all associated Room objects efficiently.
#
# ---
#
# # 12. Most Important Python Basics (Very High Probability)
#
# Students should know the following concepts thoroughly:
#
# - Variables
# - Dynamic Typing
# - Data Types
# - Lists
# - List Slicing
# - Strings
# - `for` loops
# - `if-else` statements
# - Conditional (ternary) operator
# - Functions
# - `return`
# - Keyword Arguments
# - Default Parameters
# - Classes
# - Objects
# - Constructors (`__init__`)
# - String Representation (`__str__`)
# - Assertions
# - `random.randint()`
#
# ---
#
# # Final Revision (1-Minute Review)
#
# - Python is **dynamically typed**.
# - `type()` returns the data type of an object.
# - List slicing uses the syntax `list[start:stop:step]`.
# - The **start index is included**, and the **stop index is excluded**.
# - Strings support slicing in the same way as lists.
# - `random.randint(a, b)` generates a random integer between `a` and `b` (inclusive).
# - Functions improve code reusability and modularity.
# - Keyword arguments improve readability and allow arguments to be passed in any order.
# - Default parameters provide predefined values when arguments are omitted.
# - A class is a blueprint, while an object is an instance of that class.
# - `__init__()` initializes object attributes.
# - `__str__()` defines the string representation of an object.
# - `assert` is used to validate conditions during program execution.
#
# ---
#
# # Exam Preparation Advice
#
# For a master's-level written exam, focus primarily on understanding and explaining concepts rather than memorizing code. Be prepared to:
#
# - Explain how a given Python program works.
# - Predict the output of short code snippets.
# - Describe Python concepts using proper technical terminology.
# - Distinguish between related concepts (e.g., class vs. object, function definition vs. function call).
# - Explain why a particular Python feature is used and what advantage it provides.
#
# These topics have the highest probability of appearing in theory-based Python questions in an Applied Deep Learning course.
