# %% [markdown]
# ## 🔹 Task 1: Bias Neuron

# %% [markdown]
# 1. Explain the role of a bias neuron in artificial neural networks
#
# A bias neuron is a special neuron that always has a constant value, usually 1. It is added to the weighted sum of the inputs before the activation function is applied. The main role of the bias neuron is to help the neural network adjust or shift the output of a neuron. This allows the network to learn patterns more effectively and make better predictions. Bias works similarly to the intercept term in a linear equation because it helps control where the activation starts. Without bias, the neuron output would be more restricted and less flexible.

# %% [markdown]
# 2. Describe the effects of using a bias neuron
#
# Using a bias neuron improves the flexibility and learning ability of a neural network. It allows neurons to activate even when the input values are small or zero. Bias also helps shift the decision boundary, so the network can represent more complex patterns in data. Without a bias neuron, the output is often forced to pass through the origin, which can reduce accuracy and make learning difficult. Therefore, bias neurons help the network train better and produce more accurate results.

# %% [markdown]
# ## 🔹 Task 2: Mathematical Representation of MLP Output

# %% [markdown]
# - Explain how the output of a neuron depends on:
#   - Inputs
#   - Weights
#
# Instructions:
#
# - Describe mathematically how the output of a multi-layer neural network is computed
# - Use an example of your choice
# - Explain how inference (forward propagation) works step by step

# %% [markdown]
# Q1. How does neuron output depend on inputs?
#
# The output of a neuron depends on the input values because the inputs are multiplied by weights and summed together. Different input values produce different weighted sums, which change the final output after applying the activation function.

# %% [markdown]
# Q2. How does neuron output depend on weights?
#
# Weights determine the importance of each input in a neuron. Larger weights give more influence to an input, while smaller weights reduce its effect. Negative weights can suppress the contribution of an input.

# %% [markdown]
# Q4. What is the mathematical representation of a neuron?
#
# The output of a neuron is calculated using the weighted sum of inputs and bias followed by an activation function:
#
# y=f(∑wixi + b)
#
# where:
#
# xi are inputs
#
# wi are weights
#
# b is bias
#
# f is activation function

# %% [markdown]
# ## 🔹 Task 3: Manual Forward Pass Calculation

# %% [markdown]
# # Forward Propagation in a Multi-Layer Neural Network (Manual Calculation)
#
# ## Goal
#
# Calculate:
#
# - Hidden Neurons
# - Final Output
# - Prediction Error
#
# using:
#
# - Inputs
# - Weights
# - Bias
# - Activation Function
# - Forward Propagation
#
# ---
#
# # Given
#
# ## Inputs
#
# ```text
# x₁ = 2
#
# x₂ = 1
# ```
#
# ---
#
# ## Hidden Layer Weights
#
# ### Hidden Neuron H₁
#
# ```text
# w₁₁ = 0.5
#
# w₁₂ = 0.3
#
# Bias = 0.1
# ```
#
# ### Hidden Neuron H₂
#
# ```text
# w₂₁ = 0.4
#
# w₂₂ = 0.2
#
# Bias = 0.2
# ```
#
# ---
#
# ## Output Layer Weights
#
# ```text
# v₁ = 0.6
#
# v₂ = 0.5
#
# Bias = 0.3
# ```
#
# ---
#
# ## Activation Function
#
# ReLU
#
# ```text
# ReLU(z)
#
# = max(0, z)
# ```
#
# ---
#
# ## Expected Output
#
# ```text
# Target (y) = 2.0
# ```
#
# ---
#
# # Step 1: Calculate Hidden Neuron H₁
#
# ## Weighted Sum
#
# ```text
# z₁
#
# = (x₁ × w₁₁) + (x₂ × w₁₂) + Bias
#
# = (2 × 0.5) + (1 × 0.3) + 0.1
#
# = 1.0 + 0.3 + 0.1
#
# = 1.4
# ```
#
# ## Apply Activation Function
#
# ```text
# H₁
#
# = ReLU(1.4)
#
# = max(0, 1.4)
#
# = 1.4
# ```
#
# ---
#
# # Step 2: Calculate Hidden Neuron H₂
#
# ## Weighted Sum
#
# ```text
# z₂
#
# = (x₁ × w₂₁) + (x₂ × w₂₂) + Bias
#
# = (2 × 0.4) + (1 × 0.2) + 0.2
#
# = 0.8 + 0.2 + 0.2
#
# = 1.2
# ```
#
# ## Apply Activation Function
#
# ```text
# H₂
#
# = ReLU(1.2)
#
# = max(0,1.2)
#
# = 1.2
# ```
#
# ---
#
# # Step 3: Calculate Final Output
#
# ## Weighted Sum
#
# ```text
# z
#
# = (H₁ × v₁)
#
# + (H₂ × v₂)
#
# + Bias
#
# = (1.4 × 0.6)
#
# + (1.2 × 0.5)
#
# + 0.3
#
# = 0.84
#
# + 0.60
#
# + 0.30
#
# = 1.74
# ```
#
# ## Apply Activation Function
#
# ```text
# Output
#
# = ReLU(1.74)
#
# = max(0,1.74)
#
# = 1.74
# ```
#
# ---
#
# # Step 4: Calculate Prediction Error
#
# ## Error
#
# ```text
# Prediction Error
#
# = Target − Predicted Output
#
# = 2.0 − 1.74
#
# = 0.26
# ```
#
# ---
#
# # Summary
#
# ## Hidden Layer Outputs
#
# | Hidden Neuron |   Output |
# | ------------- | -------: |
# | H₁            | **1.40** |
# | H₂            | **1.20** |
#
# ---
#
# ## Final Output
#
# ```text
# Predicted Output = 1.74
# ```
#
# ---
#
# ## Prediction Error
#
# ```text
# Prediction Error
#
# = 0.26
# ```
#
# ---
#
# # Forward Propagation Flow
#
# ```text
# Inputs
#
# x₁ = 2
# x₂ = 1
#
#         │
#         ▼
#
# Hidden Layer
#
# H₁ = 1.40
# H₂ = 1.20
#
#         │
#         ▼
#
# Output Layer
#
# Predicted Output = 1.74
#
#         │
#         ▼
#
# Target Output = 2.00
#
#         │
#         ▼
#
# Prediction Error = 0.26
# ```
#
# ---
#
# # Final Answers
#
# - **Hidden Neuron H₁ = 1.40**
# - **Hidden Neuron H₂ = 1.20**
# - **Final Output = 1.74**
# - **Prediction Error = 0.26**

# %% [markdown]
# ## 🔹 Task 4: MLP Implementation in Python

# %% [markdown]
# Implement the neural network above using:
#
# - Native Python
# - NumPy
#   ￼
#   Instructions:
# - Implement the forward pass
# - Use the same weights and parameters from Task 3
# - Test the network using:
#   x=\begin{bmatrix}1\1\end{bmatrix}
# - Compare the implementation result with your manual calculations
#
# Additional Requirement
# Instead of writing only direct calculations:
#
# - Create a class-based implementation using:
#   - Neuron objects
#   - Layer objects
#   - MLP objects
#
# 📌 Note
#
# - Focus on understanding the forward pass process
# - Carefully apply weights and activation functions
# - Compare manual calculations with implementation results

# %%
import numpy as np
class Neuron:
    def __init__(self,weights,bias):
        self.weights = np.array(weights)
        self.bias= bias

    def activation(self,x):
        if x>=0:
            return 1
        else:
            return 0

    def forward(self,inputs):
        z = np.dot(self.weights,inputs)+ self.bias
        return self.activation(z)

# %%
class Layer:

    def __init__(self, neurons):
        self.neurons = neurons

    def forward(self, inputs):
        outputs = []

        for neuron in self.neurons:
            output = neuron.forward(inputs)
            outputs.append(output)

        return outputs

# %%
class MLP:

    def __init__(self, hidden_layer, output_layer):
        self.hidden_layer = hidden_layer
        self.output_layer = output_layer

    def forward(self, inputs):

        hidden_output = self.hidden_layer.forward(inputs)

        final_output = self.output_layer.forward(hidden_output)

        return final_output[0]

    def calculate_error(self, expected, predicted):

        return 0.5 * (expected - predicted) ** 2

# %%
# Hidden layer neurons
h1 = Neuron([1.2, 0.8], -0.9)

h2 = Neuron([0.7, -0.6], -0.2)

hidden_layer = Layer([h1, h2])


# Output layer neuron
output_neuron = Neuron([-0.5, 0.5], 0.2)

output_layer = Layer([output_neuron])


# Create MLP
mlp = MLP(hidden_layer, output_layer)


# Input
x = [1, 1]


# Forward pass
y = mlp.forward(x)


# Expected output
expected = 1


# Error calculation
error = mlp.calculate_error(expected, y)


# Print results
print("Predicted Output:", y)

print("Error:", error)
# Out:
# Predicted Output: 0
# Error: 0.5
